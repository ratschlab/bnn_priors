# %%
import os
import numpy as np
import torch as t
import torchvision
from pathlib import Path
import matplotlib.pyplot as plt

from bnn_priors.data import CIFAR10

# %load_ext autoreload
# %autoreload 2

# %%
cifar10 = CIFAR10()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
cifar10.norm

# %%
cifar10.norm.train

# %%
plt.imshow(cifar10.unnorm.train.tensors[0][0].to(int));
